# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook is used for initial exploration of the intent and entity data.

# %%
import json
import pandas as pd

# Load intents data
with open('../data/intents.json', 'r') as f:
    intents_data = json.load(f)

print("Intents data loaded successfully!")
